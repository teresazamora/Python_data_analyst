# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt

from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')

df = dataset['train'].to_pandas()

# %%
df.job_posted_date = pd.to_datetime(df['job_posted_date'])

# %%
df.job_skills = df.job_skills.apply(lambda skill: ast.literal_eval(skill) if pd.notna(skill) else skill)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_DA.head(10)
# Out:
#    job_title_short                                    job_title  \
# 1     Data Analyst                                 Data Analyst
# 1     Data Analyst                                 Data Analyst
# 1     Data Analyst                                 Data Analyst
# 1     Data Analyst                                 Data Analyst
# 1     Data Analyst                                 Data Analyst
# 1     Data Analyst                                 Data Analyst
# 12    Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 12    Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 12    Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 12    Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
#
#                     job_location           job_via         job_schedule_type  \
# 1   Guadalajara, Jalisco, Mexico  via BeBee México                 Full-time
# 1   Guadalajara, Jalisco, Mexico  via BeBee México                 Full-time
# ...

# %%
df_DA = df_DA.explode('job_skills')

# %%
df_DA['job_posted_month_num'] = df_DA['job_posted_date'].dt.month

# %%
df_DA_pivot = df_DA.pivot_table(index='job_posted_month_num', columns='job_skills', aggfunc='size', fill_value=0)

# %%
df_DA_pivot
# Out:
# job_skills            airflow  airtable  alteryx  angular  angular.js  \
# job_posted_month_num
# 1                         197        17      551       63           2
# 2                         169         2      448       49           0
# 3                         181         4      442       34           0
# 4                         155         4      413       22           0
# 5                         128         8      310       30           0
# 6                         164        14      393       29           0
# 7                         207         4      366       15           0
# 8                         197         3      413       21           0
# 9                         118         4      317       21           0
# 10                        173        11      350       40           0
# 11                        169         7      293       24           0
# 12                        144        10      274       28           0
#
# ...

# %%
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()

# %%
df_DA_pivot
# Out:
# job_skills            airflow  airtable  alteryx  angular  angular.js  \
# job_posted_month_num
# 1                         197        17      551       63           2
# 2                         169         2      448       49           0
# 3                         181         4      442       34           0
# 4                         155         4      413       22           0
# 5                         128         8      310       30           0
# 6                         164        14      393       29           0
# 7                         207         4      366       15           0
# 8                         197         3      413       21           0
# 9                         118         4      317       21           0
# 10                        173        11      350       40           0
# 11                        169         7      293       24           0
# 12                        144        10      274       28           0
# ...

# %%
df_DA_pivot = df_DA_pivot.sort_values(by='Total', axis=1, ascending=False)

# %%
df_DA_pivot = df_DA_pivot.drop(index='Total')

# %%
df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# Jan               11336   8170    6606     5596      4285  3607  3830
# Feb                7947   5772    4751     3936      3307  2576  2634
# Mar                7868   5675    4741     4051      3176  2650  2554
# Apr                7553   5496    4557     3776      3106  2399  2598
# May                6617   4773    4070     3245      2695  2093  1940
# Jun                7584   5724    4707     3812      3275  2442  2174
# Jul                7687   5513    4831     3928      3350  2444  2118
# Aug                8823   6482    5576     4533      3859  2975  2560
# Sep                6829   4886    4229     3446      3118  2146  1880
# Oct                7474   5217    4693     3709      3340  2380  2114
# Nov                6652   4776    4233     3284      3012  2159  1738
# Dec                6058   4376    4196     3139      2857  2125  1858
#
# ...

# %%
df_DA_pivot = df_DA_pivot.reset_index()

# %%
df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_num'].apply(lambda month: pd.to_datetime(month, format='%m').strftime('%b'))

# %%
df_DA_pivot = df_DA_pivot.set_index('job_posted_month')

# %%
df_DA_pivot.iloc[:, :5].plot(#con il metodo iloc sono state scelte tutte le righe e solo 5 colonne
kind='line',
linewidth='3',
linestyle=':',
colormap='viridis',
marker='o',
markersize='3',figsize=(10,5)
)
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
#seconda parte
df_1 = dataset['train'].to_pandas()

# %%
df_1.job_posted_date = pd.to_datetime(df_1['job_posted_date'])

# %%
df_1.job_skills = df_1.job_skills.apply(lambda skill_1: ast.literal_eval(skill_1) if pd.notna(skill_1) else skill_1)

# %%
df_exploded = df[df['job_title_short'] == 'Data Analyst']
df_exploded
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_exploded = df_exploded.explode('job_skills')
df_exploded
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
df_final = df_exploded.groupby('job_skills').agg(
  median_salary = ('salary_year_avg', 'median'),
  count_skills = ('job_skills', 'count')
)

# %%
df_final = df_final.sort_values(by='count_skills', ascending=False).head(20)

# %%
df_final
# Out:
#             median_salary  count_skills
# job_skills
# sql          92500.000000         92428
# excel        84479.000000         66860
# python       98500.000000         57190
# tableau      95000.000000         46455
# power bi     90000.000000         39380
# r            92527.500000         29996
# sas          90000.000000         27998
# powerpoint   85000.000000         13822
# word         80000.000000         13562
# sap          90000.000000         11280
# azure       100000.000000         10913
# oracle       95000.000000         10387
# aws         100500.000000          9047
# sql server   92150.000000          8288
# go           90000.000000          7905
# flow         94450.000000          7259
# vba          90000.000000          6841
# looker      104000.000000          6259
# snowflake   110240.109375          6178
# qlik        100000.000000          5681

# %%
from adjustText import adjust_text

# %%
#fig, ax = plt.subplots()

df_final.plot(kind='scatter', x='count_skills', y='median_salary')

texts = [] # viene creata una lista perchè adjust_text come parameto prende la lista
for i,txt in enumerate(df_final.index):
  texts.append(plt.text(df_final['count_skills'].iloc[i], df_final['median_salary'].iloc[i],txt))

adjust_text(texts, # expand text bounding boxes by 1.2 fold in x direction and 2 fold in y direction
            arrowprops=dict(arrowstyle='->', color='grey', lw= 1) # ensure the labeling is clear by adding arrows
            );#questo modulo serve per avere miglior visibilità e di consegueza miglior comprensione dei dati

ax = plt.gca()


ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y,pos:f'${int(y/1000)}K'))
plt.title('Salary vs. Count of Job postitng for top 20 skills')
plt.xlabel('Skills request')
plt.ylabel('Median salary')
plt.show()
